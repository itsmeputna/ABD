# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmeputna/ABD/blob/main/crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/Drivesaya')
# Out:
# Drive already mounted at /content/Drivesaya; to attempt to forcibly remount, call drive.mount("/content/Drivesaya", force_remount=True).

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# !pip install pandas
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-0nhtnn6i
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-0nhtnn6i
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape==0.7.0.20230622) (2.31.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape==0.7.0.20230622) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape==0.7.0.20230622) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape==0.7.0.20230622) (3.12.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape==0.7.0.20230622) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.7.0.20230622) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.7.0.20230622) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.7.0.20230622) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.7.0.20230622) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.7.0.20230622) (1.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Get:5 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [3,729 B]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 15.9 kB in 2s (9,307 B/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.14).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body

# %%
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
# Out:
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main

# %%
# !sudo apt-get update
# !sudo apt-get install nodejs -y
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libc-ares2 libnode72
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   nodejs-doc
# The following packages will be upgraded:
#   nodejs
# 1 upgraded, 0 newly installed, 1 to remove and 24 not upgraded.
# Need to get 31.1 MB of archives.
# After this operation, 185 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.9.0-1nodesource1 [31.1 MB]
# Fetched 31.1 MB in 1s (61.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 121127 files and directories currently installed.)
# Removing nodejs-doc (12.22.9~dfsg-1ubuntu3.1) ...
# (Reading database ... 120948 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.9.0-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.9.0-1nodesource1) over (12.22.9~dfsg-1ubuntu3.1) ...
# Setting up nodejs (20.9.0-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !node -v
# Out:
# v20.9.0

# %%
# Crawl Data
filename = 'gibran.csv'
search_keyword = 'gibran until:2023-10-30 since:2023-09-01'
limit = 500
# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "5edb4085429302abbb076afba9a8212e97119996"
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# added 3 packages in 1s
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libatspi2.0-0 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libfontconfig1 set to manually installed.
# libnspr4 is already the newest version (2:4.32-3build1).
# libnspr4 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libgbm1 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libglib2.0-0 set to manually installed.
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libc-ares2 libnode72
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-encodings xfonts-utils xserver-common
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma xfonts-base
# The following NEW packages will be installed:
#   fonts-freefont-ttf fonts-ipafont-gothic fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont
#   fonts-wqy-zenhei libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-cyrillic xfonts-encodings
#   xfonts-scalable xfonts-utils xserver-common xvfb
# 0 upgraded, 16 newly installed, 0 to remove and 24 not upgraded.
# Need to get 29.4 MB of archives.
# After this operation, 71.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.038-0ubuntu1 [9,755 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.2 [28.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.2 [864 kB]
# Fetched 29.4 MB in 1s (34.7 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ...
0.8s155.8 Mb [] 64% 0.8s155.8 Mb [] 65% 0.8s155.8 Mb [] 66% 0.8s155.8 Mb [] 67% 0.7s155.8 Mb [] 68% 0.7s155.8 Mb [] 69% 0.7s155.8 Mb [] 70% 0.6s155.8 Mb [] 71% 0.6s155.8 Mb [] 72% 0.6s155.8 Mb [] 73% 0.6s155.8 Mb [] 75% 0.5s155.8 Mb [] 76% 0.5s155.8 Mb [] 77% 0.5s155.8 Mb [] 78% 0.5s155.8 Mb [] 79% 0.4s155.8 Mb [] 80% 0.4s155.8 Mb [] 81% 0.4s155.8 Mb [] 82% 0.4s155.8 Mb [] 83% 0.3s155.8 Mb [] 85% 0.3s155.8 Mb [] 86% 0.3s155.8 Mb [] 87% 0.3s155.8 Mb [] 88% 0.2s155.8 Mb [] 89% 0.2s155.8 Mb [] 90% 0.2s155.8 Mb [] 92% 0.2s155.8 Mb [] 93% 0.1s155.8 Mb [] 95% 0.1s155.8 Mb [] 96% 0.1s155.8 Mb [] 97% 0.1s155.8 Mb [] 98% 0.0s155.8 Mb [] 99% 0.0s155.8 Mb [] 100% 0.0s
# Chromium 119.0.6045.9 (playwright build v1084) downloaded to /root/.cache/ms-playwright/chromium-1084
# Downloading FFMPEG playwright build v1009 from https://playwright.azureedge.net/builds/ffmpeg/1009/ffmpeg-linux.zip
# 2.6 Mb [] 0% 0.0s2.6 Mb [] 4% 0.4s2.6 Mb [] 14% 0.2s2.6 Mb [] 35% 0.1s2.6 Mb [] 47% 0.1s2.6 Mb [] 69% 0.0s2.6 Mb [] 90% 0.0s2.6 Mb [] 100% 0.0s
# FFMPEG playwright build v1009 downloaded to /root/.cache/ms-playwright/ffmpeg-1009
#
# Opening twitter search page...
#
#
# Filling in keywords: gibran until:2023-10-30 since:2023-09-01
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 10
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 24
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 39
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 55
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 69
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 85
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 103
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 119
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 136
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 152
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 170
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 183
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 192
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 207
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 220
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 232
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 246
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 262
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 275
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 289
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 303
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 316
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 329
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 341
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 355
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 370
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 386
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 399
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 414
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 433
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 449
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 466
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 480
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 497
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/gibran.csv
# Total tweets saved: 514
# Already got 514 tweets, done scrolling...
# npm notice
# npm notice New minor version of npm available! 10.1.0 -> 10.2.3
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.2.3
# npm notice Run npm install -g npm@10.2.3 to update!
# npm notice

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sun Oct 29 23:59:59 +0000 2023  1718779744882405781
# 1    Sun Oct 29 23:59:48 +0000 2023  1718779700577964298
# 2    Sun Oct 29 23:59:41 +0000 2023  1718779669896720515
# 3    Sun Oct 29 23:59:39 +0000 2023  1718779663248683090
# 4    Sun Oct 29 23:59:32 +0000 2023  1718779633779478809
# ..                              ...                  ...
# 509  Sun Oct 29 23:23:50 +0000 2023  1718770649014153476
# 510  Sun Oct 29 23:23:48 +0000 2023  1718770639761473968
# 511  Sun Oct 29 23:23:46 +0000 2023  1718770630303133933
# 512  Sun Oct 29 23:23:44 +0000 2023  1718770623059734969
# 513  Sun Oct 29 23:23:38 +0000 2023  1718770596434391443
#
#                                              full_text  quote_count  \
# 0    @Nikmatul_Sg @gibran_tweet Semoga ada balasan ...            0
# 1    @yunartowijaya Sudah lah mas, iklaskan saja. I...            0
# 2    @ronnyro91579188 @jokowi SE gala HAT Inya busu...            0
# 3    @Gus_Raharjo yang jelas gibran bukan jokowi. j...            0
# 4    @Nikmatul_Sg @gibran_tweet Rakyat sekarang tid...            0
# ..                                                 ...          ...
# 509     @knpiharis @AgusYudhoyono Cium tangan k gibran            0
# 510  @Nikmatul_Sg @gibran_tweet Kalian sudah sangat...            0
# 511  @islah_bahrawi Ya iyalah...teringat jaman Pak ...            0
# 512         @gus_dibyo @gibran_tweet Fokus pakk ganjar            0
# 513  @Nikmatul_Sg @gibran_tweet berasa tersakiti ya...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              0              0               0   in  1701178754167721984
# 1              0              0               0   in  1603668632717824001
# 2              1              1               0   in  1670679995621195776
# 3              0              0               0   in  1704003841711390720
# 4              0              0               0   in  1638353548001030145
# ..           ...            ...             ...  ...                  ...
# 509            0              0               1   in  1460715225284427776
# 510            0              0               0   in  1406269729107365888
# 511            0              0               1   in  1686551963704705026
# 512            0              0               0   in  1596441014675582976
# 513            0              0               0   in  1668933562236813315
#
#      conversation_id_str         username  \
# 0    1718544255986331774       moyzaira55
# 1    1718777042991448272  ArisandiRoberto
# 2    1718278161174286419  CINTAINDONESIAd
# 3    1718392878916067582         smkkbm20
# 4    1718544255986331774   ilonkaguranska
# ..                   ...              ...
# 509  1718602190145900772  zaenala86998841
# 510  1718543282786242927      nurmadestya
# 511  1718506755439931488   TaufikAnni2671
# 512  1718622884212695534         SolimJay
# 513  1718544255986331774      lisayeppuda
#
#                                              tweet_url
# 0    https://twitter.com/moyzaira55/status/17187797...
# 1    https://twitter.com/ArisandiRoberto/status/171...
# 2    https://twitter.com/CINTAINDONESIAd/status/171...
# 3    https://twitter.com/smkkbm20/status/1718779663...
# 4    https://twitter.com/ilonkaguranska/status/1718...
# ..                                                 ...
# 509  https://twitter.com/zaenala86998841/status/171...
# 510  https://twitter.com/nurmadestya/status/1718770...
# 511  https://twitter.com/TaufikAnni2671/status/1718...
# 512  https://twitter.com/SolimJay/status/1718770623...
# 513  https://twitter.com/lisayeppuda/status/1718770...
#
# [514 rows x 12 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 514.

# %%
# Fungsi untuk menganalisis sentimen
def analisis_sentimen(teks):
    analisis = TextBlob(teks)
    if analisis.sentiment.polarity > 0:
        return 'Positif'
    elif analisis.sentiment.polarity < 0:
        return 'Negatif'
    else:
        return 'Netral'

# Menerapkan analisis sentimen pada setiap baris teks dalam DataFrame
df['Sentimen'] = df['full_text'].apply(analisis_sentimen)

# Menyimpan hasil analisis sentimen ke file CSV
df.to_csv('hasil_analisis_sentimen.csv', index=False)

print("Analisis sentimen selesai. Hasil disimpan ke 'hasil_analisis_sentimen.csv'")

Analisis sentimen selesai. Hasil disimpan ke 'hasil_analisis_sentimen.csv'
# Out:
#   File "<ipython-input-21-c09471f0746a>", line 19
#     Analisis sentimen selesai. Hasil disimpan ke 'hasil_analisis_sentimen.csv'
#              ^
# SyntaxError: invalid syntax
